# %%
from dumplings_opt import DumplingsModelBasic, DumplingsDataBasic, DumplingsMap
import matplotlib.pyplot as plt

# %%
data_b1 = DumplingsMap.from_official(1, '../data/basic_model_data')
# data_b1.print_info()

model_b1 = DumplingsModelBasic(data_b1)
sol1 = model_b1.solve()

model_b1.print_status()
sol1.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.13333333333333333
# Customer Served Ratio:  0.9333333333333333
# Object Value: 400.0

# %%
data_b2 = DumplingsMap.from_official(2, '../data/basic_model_data')
# data_b2.print_info()

model_b2 = DumplingsModelBasic(data_b2)
sol2 = model_b2.solve()

model_b2.print_status()
sol2.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.25
# Customer Served Ratio:  1.0
# Object Value: 2595.0

# %%
data_b3 = DumplingsMap.from_official(2, '../data/basic_model_data')
# data_b2.print_info()

model_b3 = DumplingsModelBasic(data_b3)
sol3 = model_b3.solve()

model_b3.print_status()
sol3.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.25
# Customer Served Ratio:  1.0
# Object Value: 2595.0

# %%
data_b3 = DumplingsMap.from_official(3, '../data/basic_model_data')
# data_b2.print_info()

model_b3 = DumplingsModelBasic(data_b3)
sol3 = model_b3.solve()

model_b3.print_status()
sol3.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.15
# Customer Served Ratio:  1.0
# Object Value: 1050.8

# %%
data_b4 = DumplingsMap.from_official(4, '../data/basic_model_data')
# data_b2.print_info()

model_b4 = DumplingsModelBasic(data_b4)
sol4 = model_b4.solve()

model_b4.print_status()
sol4.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.2
# Customer Served Ratio:  0.5172413793103449
# Object Value: 953.666666666667

# %%
data_b5 = DumplingsMap.from_official(5, '../data/basic_model_data')
# data_b2.print_info()

model_b5 = DumplingsModelBasic(data_b5)
sol5 = model_b5.solve()

model_b5.print_status()
sol5.display_connection()
# Out:
# Linear Programming Status:  Optimal
# Truck Setup Ratio:  0.125
# Customer Served Ratio:  1.0
# Object Value: 4741.999999999999
